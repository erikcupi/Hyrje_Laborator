# %% [markdown]
#  # LAB 03 : Perdorimi i Markdown dhe LaTex
# *Studenti:* Erik Cupi
#
# *Kursi:* Hyrje Laborator (Fizike dhe Shkenca Kompjuterike
#
# *Data:* 26 Mars, 2026

# %% [markdown]
# ## 1. Qëllimi i Laboratorit
# Qëllimi i këtij laboratori është aftësimi i studentit në përdorimin e gjuhës *Markdown* për strukturimin e raporteve teknike dhe përdorimin e *LaTeX* për shkrimin e formulave matematike.
#
# Objektivat kryesore përfshijnë:
# * Krijimin e titujve dhe listave të formatuara.
# * Ndërtimin e tabelave për paraqitjen e të dhënave eksperimentale.
# * Përdorimin e sintaksës LaTeX për ekuacione të ndërlikuara (thyesa, rrënjë, integrale).

# %% [markdown]
# ## 2. Ushtrime Praktike
#
# ### Ushtrimi A: Tabela e të dhënave
# Më poshtë paraqitet një tabelë me vlerat e matura gjatë simulimit:
#
# | Prova | Masa ($m$) | Nxitimi ($a$) | Forca ($F$) |
# | :--- | :---: | :---: | :---: |
# | 1 | 2.5 kg | 9.81 $m/s^2$ | 24.52 N |
# | 2 | 5.0 kg | 4.50 $m/s^2$ | 22.50 N |
# | 3 | 10.0 kg | 2.10 $m/s^2$ | 21.00 N |
#
# ### Ushtrimi B: Formulat me LaTeX
# Në këtë seksion do të paraqesim disa formula kyçe të fizikës:
#
# 1. *Ligji i dytë i Njutonit:*
#    $$F = m \cdot a$$
#
# 2. *Energjia Kinetike (me thyesë dhe fuqi):*
#    $$E_k = \frac{1}{2} m v^2$$
#
# 3. *Ekuacioni kuadratik për gjetjen e kohës ($t$):*
#    $$t = \frac{-v_0 \pm \sqrt{v_0^2 - 4ac}}{2a}$$
#
# ### Ushtrimi C: Blloku i kodit Python
# Mund të dokumentojmë kodin tonë direkt në Markdown:
# ```python
# def llogarit_forcen(m, a):
#     return m * a
#
# print(forca_rezultante = llogarit_forcen(10, 9.81))

# %% [markdown]
# ## 3. Ushtrim Shtesë: Algjebra Lineare në Fizikë
#
# Në analizat tona laboratorike, shpesh na duhet të zgjidhim sisteme ekuacionesh për të gjetur forcat në ekuilibër ose rrymat në një qark.
#
# ### A. Sistemi i Ekuacioneve
# Për të paraqitur një sistem ekuacionesh, përdorim mjedisin cases:
#
# $$
# \begin{cases}
# 2x + 3y = 10 \\
# x - y = 2
# \end{cases}
# $$
#
# ### B. Paraqitja me Matrica
# Sistemi i mësipërm mund të shkruhet në formë matricore $A \mathbf{x} = \mathbf{B}$:
#
# $$
# \begin{pmatrix}
# 2 & 3 \\
# 1 & -1
# \end{pmatrix}
# \begin{pmatrix}
# x \\
# y
# \end{pmatrix}
# =
# \begin{pmatrix}
# 10 \\
# 2
# \end{pmatrix}
# $$
#
# ### C. Llogaritja e Përcaktorit (Determinant)
# Përcaktori i matricës $A$ llogaritet si:
# $$\det(A) = |A| = (2 \cdot -1) - (3 \cdot 1) = -5$$

# %% [markdown]
# ## 3. Përfundime
# Përmes këtij laboratori u demonstrua se si dokumentimi me *Markdown* rrit qartësinë e raporteve akademike. Integrimi i *LaTeX* mundëson paraqitjen e saktë të formulave pa pasur nevojë për imazhe të jashtme, duke e bërë notebook-un plotësisht interaktiv dhe profesional për platforma si GitHub.
